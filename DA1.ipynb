# %% [markdown]
# # QUESTION 5
# Focused crawler
# Description: Crawling the documents:
# A. Start with the following seed URL from Wikipedia:
# https://en.wikipedia.org/wiki/Tropical_cyclone.
#
#
# B. Your crawler has to respect the politeness policy by using a delay of at least one second
# between your HTTP requests.
#
#
# C. Your crawler must assume that the earlier the hyperlink appears in a page, the more important
# it is (and hence must be crawled first) and that shallower depths are more important than deeper
# pages.
#
#
# D. Follow the links with the prefix https://en.wikipedia.org/wiki that lead to articles only (avoid
# administrative links containing :) Also, make sure to properly treat URLs with # which basically
# denotes a section within the (same) page and not a different one. Non-English articles, external
# links, main Wikipedia page, navigations and marginal/side links must not be followed. You may
# ignore formulas, images, and non-textual media.
#
#
# E. Crawl to depth 6. The seed page is the first URL in your frontier and thus counts for depth 1.
#
#
# F. Stop once you’ve crawled 100-500 unique URLs. Keep a list of these URLs in a text file. You
# should handle redirected pages to avoid duplicates

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import os

def spider(seed_url):
	main_page = 'https://en.wikipedia.org/wiki/Main_Page'
	crawled_count = 0
	max_depth = 1
	frontier_urls = [seed_url]
	seen_urls = []
	newpath = r'Logs' 
	if not os.path.exists(newpath):
		os.makedirs(newpath)
	crawler_log = open("Logs/crawler_log.txt","w")
	crawler_log.write("Seed : "+seed_url+"\n\n")
	crawler_log.write("Depth 1 :\n\n")
	crawled_count+=1
	crawler_log.write(str(crawled_count)+") "+seed_url+"\n\n")
	flag = True
	print("\n----------------------------------------- At depth 1--------------------------------------------------------")
	print(str(crawled_count)+") "+seed_url)
	source_code = requests.get(seed_url)
	plain_text = source_code.text
	soup = BeautifulSoup(plain_text,"html.parser")
	for depth in range (2, 7):
		if flag:
			print("\n----------------------------------------- At depth "+str(depth)+"--------------------------------------------------------")
			crawler_log.write("Depth "+str(depth)+" :\n\n")
			extracted_urls = []
			for frontier_url in frontier_urls:
				if flag:
					source_code = requests.get(frontier_url)
					plain_text = source_code.text
					soup = BeautifulSoup(plain_text,"html.parser")
					for link in soup.find_all('a', href=re.compile('^/wiki/')):
						#crawling only 250 url links
						if crawled_count < 250 and flag:
							url_text = link.text
							href_url = link.get('href')
							if ':' not in href_url:
								if '#' not in href_url:
									url = 'https://en.wikipedia.org'+href_url
									if url not in frontier_urls and url not in extracted_urls and url not in seen_urls and url != main_page:
										time.sleep(1)
										source_code = requests.get(url)
										plain_text = source_code.text
										soup = BeautifulSoup(plain_text,"html.parser")
										
										extracted_urls.append(url)
										crawled_count+=1
										crawler_log.write(str(crawled_count)+") "+url+"\n")
										print(str(crawled_count)+") "+url)

								else:
									# Handle URLs with '#'
									hash_pos = href_url.index('#')

									# Trim the URL from the start till index before '#'
									url = 'https://en.wikipedia.org'+href_url[:hash_pos]

									# URL should not be in either of Frontier, Extracted or Seen lists and should not be Wiki Main Page too
									if url not in frontier_urls and url not in extracted_urls and url not in seen_urls and url != main_page:
										
										# Respecting the Politeness Policy
										time.sleep(1)

										# get the soup
										source_code = requests.get(url)
										plain_text = source_code.text
										soup = BeautifulSoup(plain_text,"html.parser")
										extracted_urls.append(url)
										crawled_count+=1
										crawler_log.write(str(crawled_count)+") "+url+"\n")
										print(str(crawled_count)+") "+url)


						else:
							flag = False
							print("Limit of 250Ls reached")
							max_depth = depth
							break
					seen_urls.append(frontier_url)
			if len(extracted_urls) == 0:
				print("No matching URLs at Depth "+str(depth)+"\n")
				crawler_log.write("No matching URLs at Depth "+str(depth)+"\n\n")
				flag = False
				max_depth = depth
				break
			frontier_urls = extracted_urls
			crawler_log.write("\n")

	# Maximum depth of Depth 6 reached		
	if flag:
		print("Searched till max depth 6")
		max_depth = 6

	crawler_log.write("------------------------------------------------------------------------------------\n")
	crawler_log.write("Logistics :\n\n")
	crawler_log.write("Number of matching searches : "+str(crawled_count)+"\n")
	crawler_log.write("Maximum depth reached : Depth "+str(max_depth)+"\n")

seed_url = 'https://en.wikipedia.org/wiki/Tropical_cyclone'
spider(seed_url)
# Out:
# ----------------------------------------- At depth 1--------------------------------------------------------
# 1) https://en.wikipedia.org/wiki/Tropical_cyclone
#
# ----------------------------------------- At depth 2--------------------------------------------------------
# 2) https://en.wikipedia.org/wiki/Hurricane_(disambiguation)
# 3) https://en.wikipedia.org/wiki/Hurricane_No._1
# 4) https://en.wikipedia.org/wiki/Tropical_Depression_(band)
# 5) https://en.wikipedia.org/wiki/Typhoon
# 6) https://en.wikipedia.org/wiki/Hurricane_Isabel
# 7) https://en.wikipedia.org/wiki/International_Space_Station
# 8) https://en.wikipedia.org/wiki/Eye_(cyclone)
# 9) https://en.wikipedia.org/wiki/Rainband
# 10) https://en.wikipedia.org/wiki/Cyclones
# 11) https://en.wikipedia.org/wiki/Weather
# 12) https://en.wikipedia.org/wiki/Season
# 13) https://en.wikipedia.org/wiki/Winter
# 14) https://en.wikipedia.org/wiki/Spring_(season)
# 15) https://en.wikipedia.org/wiki/Summer
# 16) https://en.wikipedia.org/wiki/Autumn
# 17) https://en.wikipedia.org/wiki/Tropics
# 18) https://en.wikipedia.org/wiki/Dry_season
# 19) https://en.wikipedia.org/wiki/Harmattan
# 20) https://en.wikipedia.org/wiki/Wet_season
# 21) https://en.wikipedia.org/wiki/Storm
# 22) https://en.wikipedia.org/wiki/Cloud
# 23) https://en.wikipedia.org/wiki/Cumulonimbus_cloud
# 24) https://en.wikipedia.org/wiki/Arcus_cloud
# 25) https://en.wikipedia.org/wiki/Downburst
# 26) https://en.wikipedia.org/wiki/Microburst
# 27) https://en.wikipedia.org/wiki/Heat_burst
# 28) https://en.wikipedia.org/wiki/Derecho
# 29) https://en.wikipedia.org/wiki/Lightning
# 30) https://en.wikipedia.org/wiki/Volcanic_lightning
# 31) https://en.wikipedia.org/wiki/Thunderstorm
# 32) https://en.wikipedia.org/wiki/Air-mass_thunderstorm
# 33) https://en.wikipedia.org/wiki/Thundersnow
# 34) https://en.wikipedia.org/wiki/Dry_thunderstorm
# 35) https://en.wikipedia.org/wiki/Mesocyclone
# 36) https://en.wikipedia.org/wiki/Supercell
# 37) https://en.wikipedia.org/wiki/Tornado
# 38) https://en.wikipedia.org/wiki/Anticyclonic_tornado
# 39) https://en.wikipedia.org/wiki/Landspout
# 40) https://en.wikipedia.org/wiki/Waterspout
# 41) https://en.wikipedia.org/wiki/Dust_devil
# 42) https://en.wikipedia.org/wiki/Fire_whirl
# 43) https://en.wikipedia.org/wiki/Anticyclone
# 44) https://en.wikipedia.org/wiki/Cyclone
# 45) https://en.wikipedia.org/wiki/Polar_low
# 46) https://en.wikipedia.org/wiki/Extratropical_cyclone
# 47) https://en.wikipedia.org/wiki/European_windstorm
# 48) https://en.wikipedia.org/wiki/Nor%27easter
# 49) https://en.wikipedia.org/wiki/Subtropical_cyclone
# 50) https://en.wikipedia.org/wiki/Atlantic_hurricane
# 51) https://en.wikipedia.org/wiki/Storm_surge
# 52) https://en.wikipedia.org/wiki/Dust_storm
# 53) https://en.wikipedia.org/wiki/Simoom
# 54) https://en.wikipedia.org/wiki/Haboob
# 55) https://en.wikipedia.org/wiki/Monsoon
# 56) https://en.wikipedia.org/wiki/Amihan
# 57) https://en.wikipedia.org/wiki/Gale
# 58) https://en.wikipedia.org/wiki/Sirocco
# 59) https://en.wikipedia.org/wiki/Firestorm
# 60) https://en.wikipedia.org/wiki/Winter_storm
# 61) https://en.wikipedia.org/wiki/Ice_storm
# 62) https://en.wikipedia.org/wiki/Blizzard
# 63) https://en.wikipedia.org/wiki/Ground_blizzard
# 64) https://en.wikipedia.org/wiki/Snowsquall
# 65) https://en.wikipedia.org/wiki/Precipitation
# 66) https://en.wikipedia.org/wiki/Drizzle
# 67) https://en.wikipedia.org/wiki/Freezing_drizzle
# 68) https://en.wikipedia.org/wiki/Graupel
# 69) https://en.wikipedia.org/wiki/Hail
# 70) https://en.wikipedia.org/wiki/Megacryometeor
# 71) https://en.wikipedia.org/wiki/Ice_pellets
# 72) https://en.wikipedia.org/wiki/Diamond_dust
# 73) https://en.wikipedia.org/wiki/Rain
# 74) https://en.wikipedia.org/wiki/Freezing_rain
# 75) https://en.wikipedia.org/wiki/Cloudburst
# 76) https://en.wikipedia.org/wiki/Snow
# 77) https://en.wikipedia.org/wiki/Rain_and_snow_mixed
# 78) https://en.wikipedia.org/wiki/Snow_grains
# 79) https://en.wikipedia.org/wiki/Snow_roller
# 80) https://en.wikipedia.org/wiki/Slush
# 81) https://en.wikipedia.org/wiki/Index_of_meteorology_articles
# 82) https://en.wikipedia.org/wiki/Air_pollution
# 83) https://en.wikipedia.org/wiki/Atmosphere
# 84) https://en.wikipedia.org/wiki/Atmospheric_chemistry
# 85) https://en.wikipedia.org/wiki/Atmospheric_convection
# 86) https://en.wikipedia.org/wiki/Atmospheric_physics
# 87) https://en.wikipedia.org/wiki/Atmospheric_river
# 88) https://en.wikipedia.org/wiki/Climate
# 89) https://en.wikipedia.org/wiki/Cloud_physics
# 90) https://en.wikipedia.org/wiki/Fog
# 91) https://en.wikipedia.org/wiki/Fog_season
# 92) https://en.wikipedia.org/wiki/Cold_wave
# 93) https://en.wikipedia.org/wiki/Heat_wave
# 94) https://en.wikipedia.org/wiki/Jet_stream
# 95) https://en.wikipedia.org/wiki/Meteorology
# 96) https://en.wikipedia.org/wiki/Severe_weather
# 97) https://en.wikipedia.org/wiki/List_of_severe_weather_phenomena
# 98) https://en.wikipedia.org/wiki/Extreme_weather
# 99) https://en.wikipedia.org/wiki/Severe_weather_terminology_(Canada)
# 100) https://en.wikipedia.org/wiki/Severe_weather_terminology_(Japan)
# 101) https://en.wikipedia.org/wiki/Severe_weather_terminology_(United_States)
# 102) https://en.wikipedia.org/wiki/Weather_forecasting
# 103) https://en.wikipedia.org/wiki/Weather_modification
# 104) https://en.wikipedia.org/wiki/Glossary_of_meteorology
# 105) https://en.wikipedia.org/wiki/Glossary_of_climate_change
# 106) https://en.wikipedia.org/wiki/Glossary_of_tornado_terms
# 107) https://en.wikipedia.org/wiki/Glossary_of_tropical_cyclone_terms
# 108) https://en.wikipedia.org/wiki/Low-pressure_area
# 109) https://en.wikipedia.org/wiki/Atmospheric_circulation
# 110) https://en.wikipedia.org/wiki/Beaufort_scale
# 111) https://en.wikipedia.org/wiki/Squall
# 112) https://en.wikipedia.org/wiki/Atlantic_Ocean
# 113) https://en.wikipedia.org/wiki/Pacific_Ocean
# 114) https://en.wikipedia.org/wiki/Indian_Ocean
# 115) https://en.wikipedia.org/wiki/Clockwise_and_counterclockwise
# 116) https://en.wikipedia.org/wiki/Northern_Hemisphere
# 117) https://en.wikipedia.org/wiki/Clockwise
# 118) https://en.wikipedia.org/wiki/Southern_Hemisphere
# 119) https://en.wikipedia.org/wiki/Coriolis_effect
# 120) https://en.wikipedia.org/wiki/Tropical_cyclogenesis
# 121) https://en.wikipedia.org/wiki/Water
# 122) https://en.wikipedia.org/wiki/Ocean
# 123) https://en.wikipedia.org/wiki/Condensation
# 124) https://en.wikipedia.org/wiki/Saturated_fluid
# 125) https://en.wikipedia.org/wiki/Energy_source
# 126) https://en.wikipedia.org/wiki/Baroclinic_instability
# 127) https://en.wikipedia.org/wiki/Conservation_of_angular_momentum
# 128) https://en.wikipedia.org/wiki/Earth%27s_rotation
# 129) https://en.wikipedia.org/wiki/Wind_shear
# 130) https://en.wikipedia.org/wiki/Intertropical_Convergence_Zone
# 131) https://en.wikipedia.org/wiki/African_easterly_jet
# 132) https://en.wikipedia.org/wiki/Caribbean_Sea
# 133) https://en.wikipedia.org/wiki/Monsoon_of_South_Asia
# 134) https://en.wikipedia.org/wiki/Western_Pacific_Warm_Pool
# 135) https://en.wikipedia.org/wiki/Tornadogenesis
# 136) https://en.wikipedia.org/wiki/Flooding
# 137) https://en.wikipedia.org/wiki/Central_dense_overcast
# 138) https://en.wikipedia.org/wiki/Effects_of_tropical_cyclones
# 139) https://en.wikipedia.org/wiki/Tropical_cyclone_effects_by_region
# 140) https://en.wikipedia.org/wiki/Tropical_cyclone_warnings_and_watches
# 141) https://en.wikipedia.org/wiki/Tropical_cyclone_preparedness
# 142) https://en.wikipedia.org/wiki/Tropical_cyclone_response
# 143) https://en.wikipedia.org/wiki/Tropical_cyclone_basins
# 144) https://en.wikipedia.org/wiki/Regional_Specialized_Meteorological_Centre
# 145) https://en.wikipedia.org/wiki/Tropical_cyclone_scales
# 146) https://en.wikipedia.org/wiki/Tropical_cyclone_observation
# 147) https://en.wikipedia.org/wiki/Tropical_cyclone_forecasting
# 148) https://en.wikipedia.org/wiki/Tropical_cyclone_rainfall_forecasting
# 149) https://en.wikipedia.org/wiki/Tropical_cyclone_rainfall_climatology
# 150) https://en.wikipedia.org/wiki/List_of_tropical_cyclones
# 151) https://en.wikipedia.org/wiki/Tropical_cyclone_naming
# 152) https://en.wikipedia.org/wiki/History_of_tropical_cyclone_naming
# 153) https://en.wikipedia.org/wiki/List_of_historical_tropical_cyclone_names
# 154) https://en.wikipedia.org/wiki/List_of_retired_Atlantic_hurricane_names
# 155) https://en.wikipedia.org/wiki/List_of_retired_Pacific_hurricane_names
# 156) https://en.wikipedia.org/wiki/List_of_retired_Pacific_typhoon_names
# 157) https://en.wikipedia.org/wiki/List_of_retired_Philippine_typhoon_names
# 158) https://en.wikipedia.org/wiki/List_of_retired_Australian_region_cyclone_names
# 159) https://en.wikipedia.org/wiki/List_of_retired_South_Pacific_cyclone_names
# 160) https://en.wikipedia.org/wiki/Outline_of_tropical_cyclones
# 161) https://en.wikipedia.org/wiki/Synoptic_scale_meteorology
# 162) https://en.wikipedia.org/wiki/Subtropics
# 163) https://en.wikipedia.org/wiki/Cyclonic_rotation
# 164) https://en.wikipedia.org/wiki/2014%E2%80%9315_South-West_Indian_Ocean_cyclone_season
# 165) https://en.wikipedia.org/wiki/Convective_storm
# 166) https://en.wikipedia.org/wiki/Altitude
# 167) https://en.wikipedia.org/wiki/Rainbands
# 168) https://en.wikipedia.org/wiki/Angular_momentum
# 169) https://en.wikipedia.org/wiki/Sea_surface_temperature
# 170) https://en.wikipedia.org/wiki/Cyclonic_Ni%C3%B1o
# 171) https://en.wikipedia.org/wiki/Vorticity
# 172) https://en.wikipedia.org/wiki/Advection
# 173) https://en.wikipedia.org/wiki/Pressure_altitude
# 174) https://en.wikipedia.org/wiki/Troposphere
# 175) https://en.wikipedia.org/wiki/Latent_heat
# 176) https://en.wikipedia.org/wiki/Potential_vorticity
# 177) https://en.wikipedia.org/wiki/Trade_winds
# 178) https://en.wikipedia.org/wiki/Subtropical_ridge
# 179) https://en.wikipedia.org/wiki/Tropical_wave
# 180) https://en.wikipedia.org/wiki/Trough_(meteorology)
# 181) https://en.wikipedia.org/wiki/Coriolis_force
# 182) https://en.wikipedia.org/wiki/Beta_plane
# 183) https://en.wikipedia.org/wiki/Absolute_angular_momentum
# 184) https://en.wikipedia.org/wiki/Fujiwhara_effect
# 185) https://en.wikipedia.org/wiki/Sakuhei_Fujiwhara
# 186) https://en.wikipedia.org/wiki/Westerlies
# 187) https://en.wikipedia.org/wiki/Hurricane_Ioke
# 188) https://en.wikipedia.org/wiki/2006_Pacific_hurricane_season
# 189) https://en.wikipedia.org/wiki/Isobar_(meteorology)
# 190) https://en.wikipedia.org/wiki/Radius_of_outermost_closed_isobar
# 191) https://en.wikipedia.org/wiki/Latitude
# 192) https://en.wikipedia.org/wiki/Rapid_intensification
# 193) https://en.wikipedia.org/wiki/Tropical_Cyclone_Heat_Potential
# 194) https://en.wikipedia.org/wiki/Oceanography
# 195) https://en.wikipedia.org/wiki/Convection
# 196) https://en.wikipedia.org/wiki/2020_Atlantic_hurricane_season
# 197) https://en.wikipedia.org/wiki/Hurricane_Paulette_(2020)
# 198) https://en.wikipedia.org/wiki/Windshear
# 199) https://en.wikipedia.org/wiki/Extratropical_cyclones
# 200) https://en.wikipedia.org/wiki/Cloud_seeding
# 201) https://en.wikipedia.org/wiki/Silver_iodide
# 202) https://en.wikipedia.org/wiki/2006_Pacific_typhoon_season
# 203) https://en.wikipedia.org/wiki/Typhoon_Maria_(2006)
# 204) https://en.wikipedia.org/wiki/Typhoon_Saomai
# 205) https://en.wikipedia.org/wiki/World_Meteorological_Organization
# 206) https://en.wikipedia.org/wiki/National_Hurricane_Center
# 207) https://en.wikipedia.org/wiki/Central_Pacific_Hurricane_Center
# 208) https://en.wikipedia.org/wiki/Joint_Typhoon_Warning_Center
# 209) https://en.wikipedia.org/wiki/Japan_Meteorological_Agency
# 210) https://en.wikipedia.org/wiki/Indian_Meteorological_Department
# 211) https://en.wikipedia.org/wiki/M%C3%A9t%C3%A9o-France
# 212) https://en.wikipedia.org/wiki/Bureau_of_Meteorology_(Australia)
# 213) https://en.wikipedia.org/wiki/Fiji_Meteorological_Service
# 214) https://en.wikipedia.org/wiki/Ocean_heat_content
# 215) https://en.wikipedia.org/wiki/Dvorak_technique
# 216) https://en.wikipedia.org/wiki/Scatterometer
# 217) https://en.wikipedia.org/wiki/Mesonet
# 218) https://en.wikipedia.org/wiki/MetOp
# 219) https://en.wikipedia.org/wiki/Radiometer
# 220) https://en.wikipedia.org/wiki/Vernon_Dvorak
# 221) https://en.wikipedia.org/wiki/Cooperative_Institute_for_Meteorological_Satellite_Studies
# 222) https://en.wikipedia.org/wiki/Advanced_microwave_sounding_unit
# 223) https://en.wikipedia.org/wiki/Pacific_hurricane
# 224) https://en.wikipedia.org/wiki/International_Date_Line
# 225) https://en.wikipedia.org/wiki/Pacific_typhoon
# 226) https://en.wikipedia.org/wiki/North_Indian_Ocean_tropical_cyclone
# 227) https://en.wikipedia.org/wiki/Bay_of_Bengal
# 228) https://en.wikipedia.org/wiki/India_Meteorological_Department
# 229) https://en.wikipedia.org/wiki/Arabian_Sea
# 230) https://en.wikipedia.org/wiki/South-West_Indian_Ocean_tropical_cyclone
# 231) https://en.wikipedia.org/wiki/Australian_region_tropical_cyclone
# 232) https://en.wikipedia.org/wiki/Bureau_of_Meteorology
# 233) https://en.wikipedia.org/wiki/South_Pacific_tropical_cyclone
# 234) https://en.wikipedia.org/wiki/South_Atlantic_tropical_cyclone
# 235) https://en.wikipedia.org/wiki/United_States_Naval_Research_Laboratory
# 236) https://en.wikipedia.org/wiki/Met_Office
# 237) https://en.wikipedia.org/wiki/Automated_Tropical_Cyclone_Forecasting_System
# 238) https://en.wikipedia.org/wiki/Invest_(meteorology)
# 239) https://en.wikipedia.org/wiki/Queensland_Government
# 240) https://en.wikipedia.org/wiki/Clement_Wragge
# 241) https://en.wikipedia.org/wiki/World_War_II
# 242) https://en.wikipedia.org/wiki/Lists_of_tropical_cyclone_names
# 243) https://en.wikipedia.org/wiki/Meteorology,_Climatology,_and_Geophysical_Agency
# 244) https://en.wikipedia.org/wiki/MetService
# 245) https://en.wikipedia.org/wiki/World_Meteorological_Organisation
# 246) https://en.wikipedia.org/wiki/United_States_Government
# 247) https://en.wikipedia.org/wiki/Brazilian_Navy
# 248) https://en.wikipedia.org/wiki/Tropical_cyclone_watches_and_warnings
# 249) https://en.wikipedia.org/wiki/Heavy_rain_(meteorology)
# 250) https://en.wikipedia.org/wiki/Flood
# Limit of 250Ls reached
